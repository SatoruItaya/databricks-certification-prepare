# %%
import datetime
# list of tuple
users = [
    (
        1,
        "Corrie",
        "Van den Oord",
         "cvandenoord@etsy.com",
         True,
         1000.55,
         datetime.date(2021,1,15),
         datetime.datetime(2021, 2, 10, 1, 15, 0)
    ),
    (
        2,
        "Nikolaus",
        "Brewitt",
        "brewitt@etsy.com",
        True,
        900.55,
        datetime.date(2021,2,15),
        datetime.datetime(2021, 2, 17, 1, 15, 0)
    )
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.types import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
users_schema = StructType([
    StructField("id", IntegerType()),
    StructField("fiest_name", StringType()),
    StructField("last_name", StringType()),
    StructField("email", StringType()),
    StructField("is_customer", BooleanType()),
    StructField("amount_paid", FloatType()),
    StructField("customer_from", DateType()),
    StructField("last_updated_ts", TimestampType())
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
type(users_schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: pyspark.sql.types.StructType</div>

# %%
spark.createDataFrame(users, schema=users_schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: DataFrame[id: int, fiest_name: string, last_name: string, email: string, is_customer: boolean, amount_paid: float, customer_from: date, last_updated_ts: timestamp]</div>

# %%
spark.createDataFrame(users, schema=users_schema).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----------+------------+--------------------+-----------+-----------+-------------+-------------------+
#  id|fiest_name|   last_name|               email|is_customer|amount_paid|customer_from|    last_updated_ts|
# +---+----------+------------+--------------------+-----------+-----------+-------------+-------------------+
#   1|    Corrie|Van den Oord|cvandenoord@etsy.com|       true|    1000.55|   2021-01-15|2021-02-10 01:15:00|
#   2|  Nikolaus|     Brewitt|    brewitt@etsy.com|       true|     900.55|   2021-02-15|2021-02-17 01:15:00|
# +---+----------+------------+--------------------+-----------+-----------+-------------+-------------------+
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
