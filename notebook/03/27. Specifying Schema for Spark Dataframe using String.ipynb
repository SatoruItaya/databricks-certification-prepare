# %%
import datetime
# list of tuple
users = [
    (
        1,
        "Corrie",
        "Van den Oord",
         "cvandenoord@etsy.com",
         True,
         1000.55,
         datetime.date(2021,1,15),
         datetime.datetime(2021, 2, 10, 1, 15, 0)
    ),
    (
        2,
        "Nikolaus",
        "Brewitt",
        "brewitt@etsy.com",
        True,
        900.55,
        datetime.date(2021,2,15),
        datetime.datetime(2021, 2, 17, 1, 15, 0)
    )
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# use triple quote for multi line string
users_schema = '''
    id INT,
    first_name STRING,
    last_name STRING,
    email STRING,
    is_customer BOOLEAN,
    amount_paid FLOAT,
    custormes_from DATE,
    last_update_ts TIMESTAMP
'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.createDataFrame(users, schema=users_schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: DataFrame[id: int, first_name: string, last_name: string, email: string, is_customer: boolean, amount_paid: float, custormes_from: date, last_update_ts: timestamp]</div>

# %%
spark.createDataFrame(users, schema=users_schema).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----------+------------+--------------------+-----------+-----------+--------------+-------------------+
#  id|first_name|   last_name|               email|is_customer|amount_paid|custormes_from|     last_update_ts|
# +---+----------+------------+--------------------+-----------+-----------+--------------+-------------------+
#   1|    Corrie|Van den Oord|cvandenoord@etsy.com|       true|    1000.55|    2021-01-15|2021-02-10 01:15:00|
#   2|  Nikolaus|     Brewitt|    brewitt@etsy.com|       true|     900.55|    2021-02-15|2021-02-17 01:15:00|
# +---+----------+------------+--------------------+-----------+-----------+--------------+-------------------+
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
